# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Select stats for clustering (excluding "Type 2", name, generation, total, legendary for clustering)
cluster_features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

df_cluster = df[['Type 1', 'Name'] + cluster_features]

# %%
# Store optimal clusters and silhouette scores
optimal_clusters = {}
silhouette_scores = {}

# %%
# Iterate over each Type 1 to find the best cluster count
for poke_type in df_cluster['Type 1'].unique():
    type_df = df_cluster[df_cluster['Type 1'] == poke_type]
    X = type_df[cluster_features]

    # Define a pipeline with MinMaxScaler and KMeans
    pipeline = Pipeline([
        ('scaler', MinMaxScaler()),
        ('cluster', KMeans(random_state=0))
    ])
    
    best_score = -1
    best_k = 2
    silhouette_scores[poke_type] = []

    # Find silhouette scores for clusters ranging from 2 to 14
    for k in range(2, min(15, len(X))):
        pipeline.set_params(cluster__n_clusters=k)
        pipeline.fit(X)
        labels = pipeline.named_steps['cluster'].labels_
        
        score = silhouette_score(X, labels)
        silhouette_scores[poke_type].append((k, score))
        
        # Track the best silhouette score and cluster count
        if score > best_score:
            best_score = score
            best_k = k
    
    optimal_clusters[poke_type] = (best_k, best_score)

# %%
# Display results in specified format
for poke_type, clusters in silhouette_scores.items():
    print(f"{poke_type}\n-----------")
    for k, score in clusters:
        print(f"{k} clusters: {score}")
    
    best_k, best_score = optimal_clusters[poke_type]
    print(f"best number of clusters: {best_k}")
    print(f"best score: {best_score}\n")
    

for poke_type, clusters in silhouette_scores.items():
    print(f"{poke_type}\n-----------")
    best_k, best_score = optimal_clusters[poke_type]
    
    # Re-run clustering with the optimal number of clusters for each type
    type_df = df_cluster[df_cluster['Type 1'] == poke_type].copy()
    X = type_df[cluster_features]
    pipeline.set_params(cluster__n_clusters=best_k)
    pipeline.fit(X)
    type_df['Cluster'] = pipeline.named_steps['cluster'].labels_

    # Display clusters with mean values
    for cluster_id in range(best_k):
        cluster_data = type_df[type_df['Cluster'] == cluster_id]
        print(f"Cluster {cluster_id}")
        # print(cluster_data[["Name"] + cluster_features].to_string(index=False))
        print(cluster_data[["Name"] + cluster_features])
        
        # Calculate and display mean statistics for each cluster
        mean_stats = cluster_data[cluster_features].mean()
        print("Mean HP:", mean_stats["HP"])
        print("Mean Attack:", mean_stats["Attack"])
        print("Mean Defense:", mean_stats["Defense"])
        print("Mean Sp. Atk:", mean_stats["Sp. Atk"])
        print("Mean Sp. Def:", mean_stats["Sp. Def"])
        print("Mean Speed:", mean_stats["Speed"], "\n")
# Out:
# Grass
# -----------
# 2 clusters: 0.32466886500672937
# 3 clusters: 0.19578316342059898
# 4 clusters: 0.12714510705172744
# 5 clusters: 0.1344223618625614
# 6 clusters: 0.12584496521527
# 7 clusters: 0.13139952771002608
# 8 clusters: 0.1393127919470965
# 9 clusters: 0.13576097474075602
# 10 clusters: 0.1468445415231868
# 11 clusters: 0.1455368059913252
# 12 clusters: 0.14621654440242363
# 13 clusters: 0.1478212474796923
# 14 clusters: 0.14228469887017597
# best number of clusters: 2
# best score: 0.32466886500672937
#
# Fire
# -----------
# 2 clusters: 0.37244048426523624
# 3 clusters: 0.3530180167707559
# 4 clusters: 0.19583479899589368
# 5 clusters: 0.20180081774598946
# 6 clusters: 0.219771371151066
# 7 clusters: 0.1752488727688432
# 8 clusters: 0.1534433377918612
# 9 clusters: 0.158518931795672
# 10 clusters: 0.18724952586159632
# 11 clusters: 0.20783365962399164
# 12 clusters: 0.20324596411404908
# 13 clusters: 0.20415054615013886
# 14 clusters: 0.20419222128616207
# best number of clusters: 2
# best score: 0.37244048426523624
#
# Water
# -----------
# 2 clusters: 0.30594956822499497
# 3 clusters: 0.25460020977961434
# 4 clusters: 0.21059483471924859
# 5 clusters: 0.21517680533610856
# 6 clusters: 0.17165233325281823
# 7 clusters: 0.17460938517963917
# 8 clusters: 0.16611848154490796
# 9 clusters: 0.19163148740301436
# 10 clusters: 0.18305895403496925
# 11 clusters: 0.16211048826129953
# 12 clusters: 0.1570759265397472
# 13 clusters: 0.1600197355363385
# 14 clusters: 0.14331039613574978
# best number of clusters: 2
# best score: 0.30594956822499497
#
# Bug
# -----------
# 2 clusters: 0.3049215286212625
# 3 clusters: 0.30917277263364407
# 4 clusters: 0.2898745185277981
# 5 clusters: 0.29091121527243363
# 6 clusters: 0.2863067940885551
# 7 clusters: 0.20642716310782402
# 8 clusters: 0.21829518380704066
# 9 clusters: 0.20022630209104864
# 10 clusters: 0.19692692537254133
# 11 clusters: 0.2146529810061944
# 12 clusters: 0.2260840049527272
# 13 clusters: 0.22620085659035888
# 14 clusters: 0.22827996469797907
# best number of clusters: 3
# best score: 0.30917277263364407
#
# Normal
# -----------
# 2 clusters: 0.3086364457206219
# 3 clusters: 0.3203305632172536
# 4 clusters: 0.213848358433858
# 5 clusters: 0.3145290720046767
# 6 clusters: 0.25832614177964275
# 7 clusters: 0.22764204027305543
# 8 clusters: 0.13235198980747706
# 9 clusters: 0.15499232923761425
# 10 clusters: 0.15521507701927878
# 11 clusters: 0.17313274496480277
# 12 clusters: 0.162383697784586
# 13 clusters: 0.1570882767753089
# 14 clusters: 0.15510733737839222
# best number of clusters: 3
# best score: 0.3203305632172536
#
# Poison
# -----------
# 2 clusters: 0.4268866385541302
# 3 clusters: 0.32476250905343307
# 4 clusters: 0.2760178077618057
# 5 clusters: 0.07437937653976416
# 6 clusters: 0.10969885187978046
# 7 clusters: 0.17540804937467375
# 8 clusters: 0.06307789639145553
# 9 clusters: 0.05295512767811765
# 10 clusters: 0.03765924251235798
# 11 clusters: 0.049029686197818514
# 12 clusters: 0.06070848338759035
# 13 clusters: 0.07935595492175865
# 14 clusters: 0.10453976322201408
# best number of clusters: 2
# best score: 0.4268866385541302
#
# Electric
# -----------
# 2 clusters: 0.34648906489591447
# 3 clusters: 0.2619011381140392
# 4 clusters: 0.32710071444971694
# 5 clusters: 0.25315290720210276
# 6 clusters: 0.269854997585306
# 7 clusters: 0.2832477215072938
# 8 clusters: 0.2569271536108182
# 9 clusters: 0.2805041807383652
# 10 clusters: 0.2729533478658572
# 11 clusters: 0.29152298709417085
# 12 clusters: 0.305212035934122
# 13 clusters: 0.27976737669531254
# 14 clusters: 0.27962155383990583
# best number of clusters: 2
# best score: 0.34648906489591447
#
# Ground
# -----------
# 2 clusters: 0.34229860797096134
# 3 clusters: 0.30575440217294336
# 4 clusters: 0.25593075716703356
# 5 clusters: 0.1538404802845783
# 6 clusters: 0.14476469891651722
# 7 clusters: 0.22788266785439082
# 8 clusters: 0.24700047526631833
# 9 clusters: 0.23960084813111943
# 10 clusters: 0.19033908053625337
# 11 clusters: 0.20866105371296428
# 12 clusters: 0.19062376713435358
# 13 clusters: 0.18133435577212959
# 14 clusters: 0.20069320902200438
# best number of clusters: 2
# best score: 0.34229860797096134
#
# Fairy
# -----------
# 2 clusters: 0.3529277104874764
# 3 clusters: 0.16761030456342196
# 4 clusters: 0.1721616438822185
# 5 clusters: 0.19477553945913648
# 6 clusters: 0.2177147205047313
# 7 clusters: 0.25261232424561064
# 8 clusters: 0.23564183322927804
# 9 clusters: 0.2175429553229078
# 10 clusters: 0.054856143889597926
# 11 clusters: 0.1464967928144241
# 12 clusters: 0.11609845812394483
# 13 clusters: 0.07409345992066554
# 14 clusters: 0.05744331725269383
# best number of clusters: 2
# best score: 0.3529277104874764
#
# Fighting
# -----------
# 2 clusters: 0.3078269373948417
# 3 clusters: 0.31864655974196837
# 4 clusters: 0.31731461953791573
# 5 clusters: 0.2709403603192005
# 6 clusters: 0.22098586349836152
# 7 clusters: 0.21130848310654837
# 8 clusters: 0.2524268978695824
# 9 clusters: 0.26139082480028486
# 10 clusters: 0.25387590940007426
# 11 clusters: 0.23854792067468103
# 12 clusters: 0.25635570796090623
# 13 clusters: 0.2366487797358442
# 14 clusters: 0.235392804144892
# best number of clusters: 3
# best score: 0.31864655974196837
#
# Psychic
# -----------
# 2 clusters: 0.2847852463147622
# 3 clusters: 0.20005078301672874
# 4 clusters: 0.20315560737477611
# 5 clusters: 0.19426014253876966
# 6 clusters: 0.21909105589799924
# 7 clusters: 0.22503711865638412
# 8 clusters: 0.21805438930466442
# 9 clusters: 0.23146099667773729
# 10 clusters: 0.18046698843863673
# 11 clusters: 0.15120190684813292
# 12 clusters: 0.1439439796467839
# 13 clusters: 0.1520174744004866
# 14 clusters: 0.17123666266163926
# best number of clusters: 2
# best score: 0.2847852463147622
#
# Rock
# -----------
# 2 clusters: 0.20076136733358244
# 3 clusters: 0.22327353634252478
# 4 clusters: 0.1769307873906963
# 5 clusters: 0.17749720471847438
# 6 clusters: 0.18351528425841687
# 7 clusters: 0.21306035619910144
# 8 clusters: 0.1664286395449025
# 9 clusters: 0.17819959935910076
# 10 clusters: 0.18383584329209288
# 11 clusters: 0.16699422115148757
# 12 clusters: 0.13144333102442174
# 13 clusters: 0.16248551287512905
# 14 clusters: 0.15502575049004907
# best number of clusters: 3
# best score: 0.22327353634252478
#
# Ghost
# -----------
# 2 clusters: 0.26428811313619033
# 3 clusters: 0.20799683035190866
# 4 clusters: 0.26638497747807843
# 5 clusters: 0.28913818691757653
# 6 clusters: 0.24834402003758144
# 7 clusters: 0.28692654645435756
# 8 clusters: 0.2974682257006063
# 9 clusters: 0.31473490824587935
# 10 clusters: 0.29346767943692964
# 11 clusters: 0.27149741848335585
# 12 clusters: 0.2706486507871747
# 13 clusters: 0.2597004145064975
# 14 clusters: 0.2441446988955353
# best number of clusters: 9
# best score: 0.31473490824587935
#
# Ice
# -----------
# 2 clusters: 0.2765525488192562
# 3 clusters: 0.26048597620331293
# 4 clusters: 0.26222634355941316
# 5 clusters: 0.2421496606787018
# 6 clusters: 0.25455880480160303
# 7 clusters: 0.18311606895301744
# 8 clusters: 0.16481529130129605
# 9 clusters: 0.16702592770648242
# 10 clusters: 0.16947211711404067
# 11 clusters: 0.12064279598220962
# 12 clusters: 0.09190865938934258
# 13 clusters: 0.11046401614573755
# 14 clusters: 0.06921978009556783
# best number of clusters: 2
# best score: 0.2765525488192562
#
# Dragon
# -----------
# 2 clusters: 0.4452923709756832
# 3 clusters: 0.31281344154497503
# 4 clusters: 0.23162968048688753
# 5 clusters: 0.2607438772613963
# 6 clusters: 0.19836685126828324
# 7 clusters: 0.17614267386586271
# 8 clusters: 0.14861982863990592
# 9 clusters: 0.13890083008008788
# 10 clusters: 0.11552178290411176
# 11 clusters: 0.1295675887894797
# 12 clusters: 0.150332418840338
# 13 clusters: 0.15582313228959024
# 14 clusters: 0.15262924763229171
# best number of clusters: 2
# best score: 0.4452923709756832
#
# Dark
# -----------
# 2 clusters: 0.28686214092522866
# 3 clusters: 0.25114313131265953
# 4 clusters: 0.219959559787054
# 5 clusters: 0.2606802072267588
# 6 clusters: 0.21573955307768775
# 7 clusters: 0.22113426858484328
# 8 clusters: 0.25218813541820073
# 9 clusters: 0.24160346932048443
# 10 clusters: 0.25113516600527885
# 11 clusters: 0.254395995639403
# 12 clusters: 0.2743683311974431
# 13 clusters: 0.25828687455042804
# 14 clusters: 0.2648114858349503
# best number of clusters: 2
# best score: 0.28686214092522866
#
# Steel
# -----------
# 2 clusters: 0.24750366579235228
# 3 clusters: 0.20112430021653202
# 4 clusters: 0.2584822971682609
# 5 clusters: 0.2794031593324642
# 6 clusters: 0.20894591078740496
# 7 clusters: 0.24308616915776504
# 8 clusters: 0.2683306158566279
# 9 clusters: 0.25866543372219747
# 10 clusters: 0.23138242582308108
# 11 clusters: 0.20244926318038098
# 12 clusters: 0.19397209652990982
# 13 clusters: 0.1787998605159917
# 14 clusters: 0.16136833617803126
# best number of clusters: 5
# best score: 0.2794031593324642
#
# Flying
# -----------
# 2 clusters: 0.5294791404515692
# 3 clusters: 0.1799085675257079
# best number of clusters: 2
# best score: 0.5294791404515692
#
# Grass
# -----------
# Cluster 0
#            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0     Bulbasaur  45      49       49       65       65     45
# 1       Ivysaur  60      62       63       80       80     60
# 48       Oddish  45      50       55       75       65     30
# 49        Gloom  60      65       70       85       75     40
# 75   Bellsprout  50      75       35       70       30     40
# 76   Weepinbell  65      90       50       85       45     55
# 110   Exeggcute  60      40       80       60       45     40
# 166   Chikorita  45      49       65       49       65     45
# 167     Bayleef  60      62       80       63       80     60
# 202      Hoppip  35      35       40       35       55     50
# 203    Skiploom  55      45       50       45       65     80
# 206     Sunkern  30      30       30       30       30     30
# 272     Treecko  40      45       35       65       55     70
# 273     Grovyle  50      65       45       85       65     95
# 296      Seedot  40      40       50       30       30     30
# 297     Nuzleaf  70      70       40       60       40     60
# 309   Shroomish  60      40       60       40       60     35
# 344     Roselia  50      60       45      100       80     65
# 362      Cacnea  50      85       40       85       40     35
# 432     Turtwig  55      68       64       45       55     31
# 451       Budew  40      30       35       50       70     55
# 467     Cherubi  45      35       45       62       53     35
# 509      Snover  60      62       50       62       60     40
# 554       Snivy  45      45       55       45       55     63
# 555     Servine  60      60       75       60       75     83
# 570     Pansage  50      53       48       53       48     64
# 606    Cottonee  40      27       60       37       50     66
# 608     Petilil  45      35       50       70       50     30
# 651     Foongus  69      55       45       55       55     15
# 658   Ferroseed  44      50       91       24       86     10
# 718     Chespin  56      61       65       48       45     38
# 719   Quilladin  61      78       95       56       58     57
# 740      Skiddo  66      65       48       62       57     52
# Mean HP: 51.696969696969695
# Mean Attack: 53.96969696969697
# Mean Defense: 54.78787878787879
# Mean Sp. Atk: 58.666666666666664
# Mean Sp. Def: 57.18181818181818
# Mean Speed: 48.60606060606061
#
# Cluster 1
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2                   Venusaur   80      82       83      100      100     80
# 3      VenusaurMega Venusaur   80     100      123      122      120     80
# 50                 Vileplume   75      80       85      110       90     50
# 77                Victreebel   80     105       65      100       70     70
# 111                Exeggutor   95      95       85      125       65     55
# 122                  Tangela   65      55      115      100       40     60
# 168                 Meganium   80      82      100       83      100     80
# 197                Bellossom   75      80       95       90      100     50
# 204                 Jumpluff   75      55       70       55       95    110
# 207                 Sunflora   75      75       55      105       85     30
# 274                 Sceptile   70      85       65      105       85    120
# 275    SceptileMega Sceptile   70     110       75      145       85    145
# 298                  Shiftry   90     100       60       90       60     80
# 310                  Breloom   60     130       80       60       60     70
# 363                 Cacturne   70     115       60      115       60     55
# 390                  Tropius   99      68       83       72       87     51
# 433                   Grotle   75      89       85       55       65     36
# 434                 Torterra   95     109      105       75       85     56
# 452                 Roserade   60      70       65      125      105     90
# 468                  Cherrim   70      60       70       87       78     85
# 505                Carnivine   74     100       72       90       72     46
# 510                Abomasnow   90      92       75       92       85     60
# 511  AbomasnowMega Abomasnow   90     132      105      132      105     30
# 516                Tangrowth  100     100      125      110       50     50
# 521                  Leafeon   65     110      130       60       65     95
# 550        ShayminLand Forme  100     100      100      100      100    100
# 551         ShayminSky Forme  100     103       75      120       75    127
# 556                Serperior   75      75       95       75       95    113
# 571                 Simisage   75      98       63       98       63    101
# 607               Whimsicott   60      67       85       77       75    116
# 609                Lilligant   70      60       75      110       75     90
# 617                 Maractus   75      86       67      106       67     60
# 652                Amoonguss  114      85       70       85       80     30
# 659               Ferrothorn   74      94      131       54      116     20
# 701                 Virizion   91      90       72       90      129    108
# 720               Chesnaught   88     107      122       74       75     64
# 741                   Gogoat  123     100       62       97       81     68
# Mean HP: 81.16216216216216
# Mean Attack: 90.37837837837837
# Mean Defense: 85.08108108108108
# Mean Sp. Atk: 94.29729729729729
# Mean Sp. Def: 82.24324324324324
# Mean Speed: 73.8108108108108
#
# Fire
# -----------
# Cluster 0
#                           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 6                    Charizard   78      84       78      109       85    100
# 7    CharizardMega Charizard X   78     130      111      130       85    100
# 8    CharizardMega Charizard Y   78     104       78      159      115    100
# 43                   Ninetales   73      76       75       81      100    100
# 64                    Arcanine   90     110       80      100       80     95
# 84                    Rapidash   65     100       70       80       80    105
# 135                     Magmar   65      95       57      100       85     93
# 147                    Flareon   65     130       60       95      110     65
# 158                    Moltres   90     100       90      125       85     90
# 171                 Typhlosion   78      84       78      109       85    100
# 263                      Entei  115     115       85       90       75    100
# 270                      Ho-oh  106     130       90      110      154     90
# 278                   Blaziken   80     120       70      110       70     80
# 279      BlazikenMega Blaziken   80     160       80      130       80    100
# 353                   Camerupt   70     100       70      105       75     40
# 354      CameruptMega Camerupt   70     120      100      145      105     20
# 355                    Torkoal   70      85      140       85       70     20
# 437                  Infernape   76     104       71      104       71    108
# 518                  Magmortar   75      95       67      125       95     83
# 542                    Heatran   91      90      106      130      106     77
# 559                     Emboar  110     123       65      100       65     65
# 573                   Simisear   75      98       63       98       63    101
# 615    DarmanitanStandard Mode  105     140       55       30       55     95
# 616         DarmanitanZen Mode  105      30      105      140      105     55
# 692                    Heatmor   85      97       66      105       66     65
# 723                    Delphox   75      69       72      114      100    104
# 731                 Talonflame   78      81       71       74       69    126
# 736                     Pyroar   86      68       72      109       66    106
# 799                  Volcanion   80     110      120      130       90     70
# Mean HP: 82.48275862068965
# Mean Attack: 101.65517241379311
# Mean Defense: 80.86206896551724
# Mean Sp. Atk: 107.65517241379311
# Mean Sp. Def: 85.86206896551724
# Mean Speed: 84.58620689655173
#
# Cluster 1
#             Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 4     Charmander  39      52       43       60       50     65
# 5     Charmeleon  58      64       58       80       65     80
# 42        Vulpix  38      41       40       50       65     65
# 63     Growlithe  55      70       45       70       50     60
# 83        Ponyta  50      85       55       65       65     90
# 169    Cyndaquil  39      52       43       60       50     65
# 170      Quilava  58      64       58       80       65     80
# 236       Slugma  40      40       40       70       40     20
# 237     Magcargo  50      50      120       80       80     30
# 259        Magby  45      75       37       70       55     83
# 276      Torchic  45      60       40       70       50     45
# 277    Combusken  60      85       60       85       60     55
# 352        Numel  60      60       40       65       45     35
# 435     Chimchar  44      58       44       58       44     61
# 436     Monferno  64      78       52       78       52     81
# 557        Tepig  65      63       45       45       45     45
# 558      Pignite  90      93       55       70       55     55
# 572      Pansear  50      53       48       53       48     64
# 614     Darumaka  70      90       45       15       45     50
# 721     Fennekin  40      45       40       62       60     60
# 722      Braixen  59      59       58       90       70     73
# 730  Fletchinder  62      73       55       56       52     84
# 735       Litleo  62      50       58       73       54     72
# Mean HP: 54.04347826086956
# Mean Attack: 63.47826086956522
# Mean Defense: 51.26086956521739
# Mean Sp. Atk: 65.43478260869566
# Mean Sp. Def: 55.0
# Mean Speed: 61.65217391304348
#
# Water
# -----------
# Cluster 0
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 11                 Blastoise   79      83      100       85      105     78
# 12   BlastoiseMega Blastoise   79     103      120      135      115     78
# 60                   Golduck   80      82       78       95       80     85
# 67                 Poliwrath   90      95       95       70       90     70
# 79                Tentacruel   80      70       65       80      120    100
# 86                   Slowbro   95      75      110      100       80     30
# 87       SlowbroMega Slowbro   95      75      180      130       80     30
# 94                   Dewgong   90      70       80       70       95     70
# 98                  Cloyster   50      95      180       85       45     70
# 107                  Kingler   55     130      115       50       50     75
# 126                   Seadra   55      65       95       95       45     85
# 128                  Seaking   80      92       65       65       80     68
# 130                  Starmie   60      75       85      100       85    115
# 140                 Gyarados   95     125       79       60      100     81
# 141    GyaradosMega Gyarados   95     155      109       70      130     81
# 142                   Lapras  130      85       80       85       95     60
# 145                 Vaporeon  130      65       60      110       95     65
# 174               Feraligatr   85     105      100       79       83     78
# 185                  Lanturn  125      58       58       76       76     67
# 201                 Politoed   90      75       75       90      100     70
# 210                 Quagsire   95      85       85       65       65     35
# 214                 Slowking   95      75       80      100      110     30
# 227                 Qwilfish   65      95       75       55       55     85
# 242                Octillery   75     105       75      105       75     45
# 244                  Mantine   65      40       70       80      140     70
# 249                  Kingdra   75      95       95       95       95     85
# 264                  Suicune  100      75      115       90      115     85
# 282                 Swampert  100     110       90       85       90     60
# 283    SwampertMega Swampert  100     150      110       95      110     70
# 295                 Ludicolo   80      70       70       90      100     70
# 348                 Sharpedo   70     120       40       95       40     95
# 349    SharpedoMega Sharpedo   70     140       70      110       65    105
# 351                  Wailord  170      90       45       90       45     60
# 372                 Whiscash  110      78       73       76       71     60
# 374                Crawdaunt   63     120       85       90       55     55
# 382                  Milotic   95      60       79      100      125     81
# 402                  Huntail   55     104      105       94       75     52
# 403                 Gorebyss   55      84      105      114       75     52
# 404                Relicanth  100      90      130       45       65     55
# 421                   Kyogre  100     100       90      150      140     90
# 422      KyogrePrimal Kyogre  100     150       90      180      160     90
# 440                 Empoleon   84      86       88      111      101     60
# 466                 Floatzel   85     105       55       85       50    115
# 470                Gastrodon  111      83       68       92       82     39
# 507                 Lumineon   69      69       76       69       86     91
# 541                   Palkia   90     120      100      150      120    100
# 547                   Phione   80      80       80       80       80     80
# 548                  Manaphy  100     100      100      100      100    100
# 562                 Samurott   95     100       85      108       70     70
# 575                 Simipour   75      98       63       98       63    101
# 597               Seismitoad  105      95       75       85       75     74
# 610                 Basculin   70      92       65       80       55     98
# 626               Carracosta   74     108      133       83       65     32
# 642                   Swanna   75      87       63       87       63     98
# 654                Jellicent  100      60       70       85      105     60
# 655                Alomomola  165      75       80       40       45     65
# 713     KeldeoOrdinary Forme   91      72       90      129       90    108
# 714     KeldeoResolute Forme   91      72       90      129       90    108
# 726                 Greninja   72      95       67      103       71    122
# 763                Clawitzer   71      73       88      120       89     59
# Mean HP: 87.98333333333333
# Mean Attack: 91.4
# Mean Defense: 87.36666666666666
# Mean Sp. Atk: 92.8
# Mean Sp. Def: 85.33333333333333
# Mean Speed: 74.43333333333334
#
# Cluster 1
#           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 9     Squirtle   44      48       65       50       64     43
# 10   Wartortle   59      63       80       65       80     58
# 59     Psyduck   50      52       48       65       50     55
# 65     Poliwag   40      50       40       40       40     90
# 66   Poliwhirl   65      65       65       50       50     90
# 78   Tentacool   40      40       35       50      100     70
# 85    Slowpoke   90      65       65       40       40     15
# 93        Seel   65      45       55       45       70     45
# 97    Shellder   30      65      100       45       25     40
# 106     Krabby   30     105       90       25       25     50
# 125     Horsea   30      40       70       70       25     60
# 127    Goldeen   45      67       60       35       50     63
# 129     Staryu   30      45       55       70       55     85
# 139   Magikarp   20      10       55       15       20     80
# 172   Totodile   50      65       64       44       48     43
# 173   Croconaw   65      80       80       59       63     58
# 184   Chinchou   75      38       38       56       56     67
# 198     Marill   70      20       50       20       50     40
# 199  Azumarill  100      50       80       60       80     50
# 209     Wooper   55      45       45       25       25     15
# 240    Corsola   55      55       85       65       85     35
# 241   Remoraid   35      65       35       65       35     65
# 280     Mudkip   50      70       50       50       50     40
# 281  Marshtomp   70      85       70       60       70     50
# 293      Lotad   40      30       30       40       50     30
# 294     Lombre   60      50       50       60       70     50
# 301    Wingull   40      30       30       55       30     85
# 302   Pelipper   60      50      100       85       70     65
# 347   Carvanha   45      90       20       65       20     65
# 350    Wailmer  130      70       35       70       35     60
# 371   Barboach   50      48       43       46       41     60
# 373   Corphish   43      80       65       50       35     35
# 381     Feebas   20      15       20       10       55     80
# 401   Clamperl   35      64       85       74       55     32
# 405    Luvdisc   43      30       55       40       65     97
# 438     Piplup   53      51       53       61       56     40
# 439   Prinplup   64      66       68       81       76     50
# 465     Buizel   55      65       35       60       30     85
# 469    Shellos   76      48       48       57       62     34
# 506    Finneon   49      49       56       49       61     66
# 508    Mantyke   45      20       50       60      120     50
# 560   Oshawott   55      55       45       63       45     45
# 561     Dewott   75      75       60       83       60     60
# 574    Panpour   50      53       48       53       48     64
# 595    Tympole   50      50       40       50       40     64
# 596  Palpitoad   75      65       55       65       55     69
# 625   Tirtouga   54      78      103       53       45     22
# 641   Ducklett   62      44       50       44       50     55
# 653   Frillish   55      40       50       65       85     40
# 724    Froakie   41      56       40       62       44     71
# 725  Frogadier   54      63       52       83       56     97
# 762  Clauncher   50      53       62       58       63     44
# Mean HP: 53.69230769230769
# Mean Attack: 54.25
# Mean Defense: 56.30769230769231
# Mean Sp. Atk: 54.05769230769231
# Mean Sp. Def: 53.42307692307692
# Mean Speed: 56.19230769230769
#
# Bug
# -----------
# Cluster 0
#                         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 15                Butterfree  60      45       50       90       80     70
# 18                  Beedrill  65      90       40       45       80     75
# 19     BeedrillMega Beedrill  65     150       40       15       80    145
# 52                  Parasect  60      95       80       60       80     30
# 54                  Venomoth  70      65       60       90       75     90
# 132                  Scyther  70     110       80       55       80    105
# 136                   Pinsir  65     125      100       55       70     85
# 137        PinsirMega Pinsir  65     155      120       65       90    105
# 180                   Ledian  55      35       50       55      110     85
# 182                  Ariados  70      90       70       60       60     40
# 208                    Yanma  65      65       45       75       45     95
# 220               Forretress  75      90      140       60       60     40
# 228                   Scizor  70     130      100       55       80     65
# 229        ScizorMega Scizor  70     150      140       65      100     75
# 231                Heracross  80     125       75       40       95     85
# 232  HeracrossMega Heracross  80     185      115       40      105     75
# 290                Beautifly  60      70       50      100       50     65
# 292                   Dustox  60      50       70       50       90     65
# 308               Masquerain  70      60       62       80       82     60
# 315                  Ninjask  61      90       45       50       50    160
# 342                  Volbeat  65      73       55       47       75     85
# 343                 Illumise  65      47       55       73       75     85
# 447               Kricketune  77      85       51       55       51     65
# 458      WormadamPlant Cloak  60      59       85       79      105     36
# 459      WormadamSandy Cloak  60      79      105       59       85     36
# 460      WormadamTrash Cloak  60      69       95       69       95     36
# 461                   Mothim  70      94       50       94       50     66
# 463                Vespiquen  70      80      102       80      102     40
# 520                  Yanmega  86      76       86      116       56     95
# 602                 Leavanny  75     103       80       70       80     92
# 605                Scolipede  60     100       89       55       69    112
# 619                  Crustle  70      95      125       65       75     45
# 650               Escavalier  70     135      105       60      105     20
# 657               Galvantula  70      77       60       97       60    108
# 678                 Accelgor  80      70       40      100       60    145
# 693                   Durant  58     109      112       48       48    109
# 697                 Larvesta  55      85       55       50       55     60
# 698                Volcarona  85      60       65      135      105    100
# 717                 Genesect  71     120       95      120       95     99
# 734                 Vivillon  80      52       50       90       50     89
# Mean HP: 68.075
# Mean Attack: 91.075
# Mean Defense: 77.3
# Mean Sp. Atk: 69.175
# Mean Sp. Def: 76.45
# Mean Speed: 78.45
#
# Cluster 1
#            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 13     Caterpie  45      30       35       20       20     45
# 14      Metapod  50      20       55       25       25     30
# 16       Weedle  40      35       30       20       20     50
# 17       Kakuna  45      25       50       25       25     35
# 51        Paras  35      70       55       45       55     25
# 53      Venonat  60      55       50       40       55     45
# 179      Ledyba  40      20       30       40       80     55
# 181    Spinarak  40      60       40       40       40     30
# 219      Pineco  50      65       90       35       35     15
# 288     Wurmple  45      45       35       20       30     20
# 289     Silcoon  50      35       55       25       25     15
# 291     Cascoon  50      35       55       25       25     15
# 307     Surskit  40      30       32       50       52     65
# 314     Nincada  31      45       90       30       30     40
# 316    Shedinja   1      90       45       30       30     40
# 446   Kricketot  37      25       41       25       41     25
# 457       Burmy  40      29       45       29       45     36
# 462      Combee  30      30       42       30       42     70
# 600    Sewaddle  45      53       70       40       60     42
# 601    Swadloon  55      63       90       50       80     42
# 603    Venipede  30      45       59       30       39     57
# 604  Whirlipede  40      55       99       40       79     47
# 618     Dwebble  50      65       85       35       35     55
# 649  Karrablast  50      75       45       40       45     60
# 656      Joltik  50      47       50       57       50     65
# 677     Shelmet  50      40       85       40       65     25
# 732  Scatterbug  38      35       40       27       25     35
# 733      Spewpa  45      22       60       27       30     29
# Mean HP: 42.214285714285715
# Mean Attack: 44.42857142857143
# Mean Defense: 55.642857142857146
# Mean Sp. Atk: 33.57142857142857
# Mean Sp. Def: 42.25
# Mean Speed: 39.75
#
# Cluster 2
#         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 230  Shuckle  20      10      230       10      230      5
# Mean HP: 20.0
# Mean Attack: 10.0
# Mean Defense: 230.0
# Mean Sp. Atk: 10.0
# Mean Sp. Def: 230.0
# Mean Speed: 5.0
#
# Normal
# -----------
# Cluster 0
#                    Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 45           Wigglytuff  140      70       45       85       50     45
# 116           Lickitung   90      55       75       60       75     30
# 121             Chansey  250       5        5       35      105     50
# 148             Porygon   65      60       70       85       75     40
# 155             Snorlax  160     110       65       65      110     30
# 178             Noctowl  100      50       50       76       96     70
# 221           Dunsparce  100      70       70       65       65     45
# 252            Porygon2   85      80       90      105       95     60
# 261             Blissey  255      10       10       75      135     55
# 319             Exploud  104      91       63       91       73     68
# 384             Kecleon   60      90       70       60      120     40
# 495            Munchlax  135      85       40       40       85      5
# 514          Lickilicky  110      85       95       80       95     50
# 590              Audino  103      60       86       60       86     50
# 591   AudinoMega Audino  103      60      126       80      126     50
# 687          Bouffalant   95     110       95       40       95     55
# 715  MeloettaAria Forme  100      77       77      128      128     90
# Mean HP: 120.88235294117646
# Mean Attack: 68.70588235294117
# Mean Defense: 66.58823529411765
# Mean Sp. Atk: 72.3529411764706
# Mean Sp. Def: 94.94117647058823
# Mean Speed: 49.0
#
# Cluster 1
#                           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 22                     Pidgeot   83      80       75       70       70    101
# 23         PidgeotMega Pidgeot   83      80       80      135       80    121
# 25                    Raticate   55      81       60       50       70     97
# 27                      Fearow   65      90       65       61       61    100
# 58                     Persian   65      70       60       65       65    115
# 92                      Dodrio   60     110       70       60       60    100
# 123                 Kangaskhan  105      95       80       40       80     90
# 124  KangaskhanMega Kangaskhan  105     125      100       60      100    100
# 138                     Tauros   75     100       95       40       70    110
# 176                     Furret   85      76       64       45       55     90
# 218                  Girafarig   70      80       65       90       65     85
# 235                   Ursaring   90     130       75       75       75     55
# 253                   Stantler   73      95       62       85       65     85
# 260                    Miltank   95      80      105       40       70    100
# 287                    Linoone   78      70       61       50       61    100
# 300                    Swellow   60      85       60       50       50    125
# 312                   Vigoroth   80      80       80       55       55     90
# 313                    Slaking  150     160      100       95       65    100
# 367                   Zangoose   73     115       60       60       60     90
# 383                   Castform   70      70       70       70       70     70
# 443                  Staraptor   85     120       70       50       60    100
# 445                    Bibarel   79      85       60       55       60     71
# 471                    Ambipom   75     100       66       60       66    115
# 475                    Lopunny   65      76       84       54       96    105
# 476        LopunnyMega Lopunny   65     136       94       54       96    135
# 480                    Purugly   71      82       64       64       59    112
# 489                     Chatot   76      65       45       92       42     91
# 525                  Porygon-Z   85      80       70      135       75     90
# 543                  Regigigas  110     160      110       80      110    100
# 552                     Arceus  120     120      120      120      120    120
# 564                    Watchog   60      85       69       60       69     77
# 567                  Stoutland   85     110       90       45       90     80
# 580                   Unfezant   80     115       80       65       55     93
# 634                   Cinccino   75      95       60       65       60    115
# 647                   Sawsbuck   80     100       70       60       70     95
# 689                   Braviary  100     123       75       57       75     80
# 716    MeloettaPirouette Forme  100     128       90       77       77    128
# 728                  Diggersby   85      56       77       50       77     78
# 744                    Furfrou   75      80       60       65       90    102
# Mean HP: 81.82051282051282
# Mean Attack: 97.12820512820512
# Mean Defense: 75.41025641025641
# Mean Sp. Atk: 66.76923076923077
# Mean Sp. Def: 71.64102564102564
# Mean Speed: 97.71794871794872
#
# Cluster 2
#            Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 20       Pidgey   40      45       40       35       35     56
# 21    Pidgeotto   63      60       55       50       50     71
# 24      Rattata   30      56       35       25       35     72
# 26      Spearow   40      60       30       31       31     70
# 44   Jigglypuff  115      45       20       45       25     20
# 57       Meowth   40      45       35       40       40     90
# 90   Farfetch'd   52      65       55       58       62     60
# 91        Doduo   35      85       45       35       35     75
# 143       Ditto   48      48       48       48       48     48
# 144       Eevee   55      55       50       45       65     55
# 175     Sentret   35      46       34       35       45     20
# 177    Hoothoot   60      30       30       36       56     50
# 188   Igglybuff   90      30       15       40       20     15
# 205       Aipom   55      70       55       40       55     85
# 234   Teddiursa   60      80       50       50       50     40
# 254    Smeargle   55      20       35       20       45     75
# 286   Zigzagoon   38      30       41       30       41     60
# 299     Taillow   40      55       30       30       30     85
# 311     Slakoth   60      60       60       35       35     30
# 317     Whismur   64      51       23       51       23     28
# 318     Loudred   84      71       43       71       43     48
# 322     Azurill   50      20       40       20       40     20
# 324      Skitty   50      45       45       35       35     50
# 325    Delcatty   70      65       65       55       55     70
# 358      Spinda   60      60       60       60       60     60
# 364      Swablu   45      40       60       40       75     50
# 441      Starly   40      55       30       30       30     60
# 442    Staravia   55      75       50       40       40     80
# 444      Bidoof   59      45       40       35       40     31
# 474     Buneary   55      66       44       44       56     85
# 479     Glameow   49      55       42       42       37     85
# 488     Happiny  100       5        5       15       65     30
# 563      Patrat   45      55       39       35       39     42
# 565    Lillipup   45      60       45       25       45     55
# 566     Herdier   65      80       65       35       65     60
# 578      Pidove   50      55       50       36       30     43
# 579   Tranquill   62      77       62       50       42     65
# 633    Minccino   55      50       40       40       40     75
# 646    Deerling   60      60       50       40       50     75
# 688     Rufflet   70      83       50       37       50     60
# 727    Bunnelby   38      36       38       32       36     57
# 729  Fletchling   45      50       43       40       38     62
# Mean HP: 55.404761904761905
# Mean Attack: 53.42857142857143
# Mean Defense: 42.666666666666664
# Mean Sp. Atk: 38.95238095238095
# Mean Sp. Def: 43.73809523809524
# Mean Speed: 56.38095238095238
#
# Poison
# -----------
# Cluster 0
#          Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 28      Ekans  35      60       44       40       54     55
# 34   Nidoran?  55      47       52       40       40     41
# 35   Nidorina  70      62       67       55       55     56
# 37   Nidoran?  46      57       40       40       40     50
# 38   Nidorino  61      72       57       55       55     65
# 46      Zubat  40      45       35       30       40     55
# 95     Grimer  80      80       50       40       50     25
# 117   Koffing  40      65       95       60       45     35
# 345    Gulpin  70      43       53       43       53     40
# 482    Stunky  63      63       47       41       41     74
# 501   Skorupi  40      50       90       30       55     65
# 503  Croagunk  48      61       40       61       40     50
# 629  Trubbish  50      50       62       40       62     65
# 760    Skrelp  50      60       60       60       60     30
# Mean HP: 53.42857142857143
# Mean Attack: 58.214285714285715
# Mean Defense: 56.57142857142857
# Mean Sp. Atk: 45.357142857142854
# Mean Sp. Def: 49.285714285714285
# Mean Speed: 50.42857142857143
#
# Cluster 1
#           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 29       Arbok   60      85       69       65       79     80
# 36   Nidoqueen   90      92       87       75       85     76
# 39    Nidoking   81     102       77       85       75     85
# 47      Golbat   75      80       70       65       75     90
# 96         Muk  105     105       75       65      100     50
# 118    Weezing   65      90      120       85       70     60
# 183     Crobat   85      90       80       70       80    130
# 346     Swalot  100      73       83       73       83     55
# 368    Seviper   73     100       60      100       60     65
# 483   Skuntank  103      93       67       71       61     84
# 502    Drapion   70      90      110       60       75     95
# 504  Toxicroak   83     106       65       86       65     85
# 630   Garbodor   80      95       82       60       82     75
# 761   Dragalge   65      75       90       97      123     44
# Mean HP: 81.07142857142857
# Mean Attack: 91.14285714285714
# Mean Defense: 81.07142857142857
# Mean Sp. Atk: 75.5
# Mean Sp. Def: 79.5
# Mean Speed: 76.71428571428571
#
# Electric
# -----------
# Cluster 0
#            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 30      Pikachu  35      55       40       50       50     90
# 88    Magnemite  25      35       70       95       55     45
# 108     Voltorb  40      30       50       55       55    100
# 186       Pichu  20      40       15       35       35     60
# 193      Mareep  55      40       40       65       45     35
# 194     Flaaffy  70      55       55       80       60     45
# 258      Elekid  45      63       37       65       55     95
# 337   Electrike  40      45       40       65       40     65
# 340      Plusle  60      50       40       85       75     95
# 341       Minun  60      40       50       75       85     95
# 448       Shinx  45      65       34       40       34     45
# 449       Luxio  60      85       49       60       49     60
# 464   Pachirisu  60      45       70       45       90     95
# 581     Blitzle  45      60       32       50       32     76
# 648      Emolga  55      75       60       75       60    103
# 663      Tynamo  35      55       40       45       40     60
# 664   Eelektrik  65      85       70       75       70     40
# 764  Helioptile  44      38       33       61       43     70
# 772     Dedenne  67      58       57       81       67    101
# Mean HP: 48.73684210526316
# Mean Attack: 53.63157894736842
# Mean Defense: 46.421052631578945
# Mean Sp. Atk: 63.26315789473684
# Mean Sp. Def: 54.73684210526316
# Mean Speed: 72.36842105263158
#
# Cluster 1
#                          Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 31                     Raichu  60      90       55       90       80    110
# 89                   Magneton  50      60       95      120       70     70
# 109                 Electrode  60      50       70       80       80    140
# 134                Electabuzz  65      83       57       95       85    105
# 146                   Jolteon  65      65       60      110       95    130
# 157                    Zapdos  90      90       85      125       90    100
# 195                  Ampharos  90      75       85      115       90     55
# 196     AmpharosMega Ampharos  90      95      105      165      110     45
# 262                    Raikou  90      85       75      115      100    115
# 338                 Manectric  70      75       60      105       60    105
# 339   ManectricMega Manectric  70      75       80      135       80    135
# 450                    Luxray  80     120       79       95       79     70
# 513                 Magnezone  70      70      115      130       90     60
# 517                Electivire  75     123       67       95       85     95
# 531                     Rotom  50      50       77       95       77     91
# 532           RotomHeat Rotom  50      65      107      105      107     86
# 533           RotomWash Rotom  50      65      107      105      107     86
# 534          RotomFrost Rotom  50      65      107      105      107     86
# 535            RotomFan Rotom  50      65      107      105      107     86
# 536            RotomMow Rotom  50      65      107      105      107     86
# 582                 Zebstrika  75     100       63       80       63    116
# 665                Eelektross  85     115       80      105       80     50
# 704  ThundurusIncarnate Forme  79     115       70      125       80    111
# 705    ThundurusTherian Forme  79     105       70      145       80    101
# 765                 Heliolisk  62      55       52      109       94    109
# Mean HP: 68.2
# Mean Attack: 80.84
# Mean Defense: 81.4
# Mean Sp. Atk: 110.36
# Mean Sp. Def: 88.12
# Mean Speed: 93.72
#
# Ground
# -----------
# Cluster 0
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 423                  Groudon  100     150      140      100       90     90
# 424    GroudonPrimal Groudon  100     180      160      150       90     90
# 708  LandorusIncarnate Forme   89     125       90      115       80    101
# 709    LandorusTherian Forme   89     145       90      105       80     91
# Mean HP: 94.5
# Mean Attack: 150.0
# Mean Defense: 120.0
# Mean Sp. Atk: 117.5
# Mean Sp. Def: 85.0
# Mean Speed: 93.0
#
# Cluster 1
#            Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 32    Sandshrew   50      75       85       20       30     40
# 33    Sandslash   75     100      110       45       55     65
# 55      Diglett   10      55       25       35       45     95
# 56      Dugtrio   35      80       50       50       70    120
# 112      Cubone   50      50       95       40       50     35
# 113     Marowak   60      80      110       50       80     45
# 119     Rhyhorn   80      85       95       30       30     25
# 120      Rhydon  105     130      120       45       45     40
# 222      Gligar   65      75      105       35       65     85
# 250      Phanpy   90      60       60       40       40     40
# 251     Donphan   90     120      120       60       60     50
# 359    Trapinch   45     100       45       45       45     10
# 360     Vibrava   50      70       50       50       50     70
# 361      Flygon   80     100       80       80       80    100
# 375      Baltoy   40      40       55       40       70     55
# 376     Claydol   60      70      105       70      120     75
# 499  Hippopotas   68      72       78       38       42     32
# 500   Hippowdon  108     112      118       68       72     47
# 515   Rhyperior  115     140      130       55       55     40
# 523     Gliscor   75      95      125       45       75     95
# 588     Drilbur   60      85       40       30       45     68
# 589   Excadrill  110     135       60       50       65     88
# 611     Sandile   50      72       35       35       35     65
# 612    Krokorok   60      82       45       45       45     74
# 613  Krookodile   95     117       80       65       70     92
# 679    Stunfisk  109      66       84       81       99     32
# 683      Golett   59      74       50       35       50     35
# 684      Golurk   89     124       80       55       80     55
# Mean HP: 70.82142857142857
# Mean Attack: 88.0
# Mean Defense: 79.82142857142857
# Mean Sp. Atk: 47.75
# Mean Sp. Def: 59.57142857142857
# Mean Speed: 59.75
#
# Fairy
# -----------
# Cluster 0
#          Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...
# 453    Cranidos  67     125       40       30       30     58
# 486      Bonsly  50      80       95       10       45     10
# 583  Roggenrola  55      75       85       25       25     15
# 584     Boldore  70     105      105       50       40     20
# 585    Gigalith  85     135      130       60       80     25
# 627      Archen  55     112       45       74       45     70
# 758     Binacle  42      52       67       39       56     50
# 759  Barbaracle  72     105      115       54       86     68
# 766      Tyrunt  58      89       77       45       45     48
# 768      Amaura  77      59       50       67       63     46
# Mean HP: 60.76190476190476
# Mean Attack: 94.76190476190476
# Mean Defense: 86.61904761904762
# Mean Sp. Atk: 48.04761904761905
# Mean Sp. Def: 54.76190476190476
# Mean Speed: 45.57142857142857
#
# Ghost
# -----------
# Cluster 0
#         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 388  Duskull  20      40       90       30       90     25
# 623   Yamask  38      30       85       55       65     30
# 668  Litwick  50      30       55       65       55     20
# Mean HP: 36.0
# Mean Attack: 33.333333333333336
# Mean Defense: 76.66666666666667
# Mean Sp. Atk: 50.0
# Mean Sp. Def: 70.0
# Mean Speed: 25.0
#
# Cluster 1
#                       Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 544  GiratinaAltered Forme  150     100      120      100      120     90
# 545   GiratinaOrigin Forme  150     120      100      120      100     90
# Mean HP: 150.0
# Mean Attack: 110.0
# Mean Defense: 110.0
# Mean Sp. Atk: 110.0
# Mean Sp. Def: 110.0
# Mean Speed: 90.0
#
# Cluster 2
#                       Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 784  GourgeistAverage Size  65      90      122       58       75     84
# 785    GourgeistSmall Size  55      85      122       58       75     99
# 786    GourgeistLarge Size  75      95      122       58       75     69
# 787    GourgeistSuper Size  85     100      122       58       75     54
# Mean HP: 70.0
# Mean Attack: 92.5
# Mean Defense: 122.0
# Mean Sp. Atk: 58.0
# Mean Sp. Def: 75.0
# Mean Speed: 76.5
#
# Cluster 3
#                     Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 386              Banette  64     115       65       83       63     65
# 387  BanetteMega Banette  64     165       75       93       83     75
# 779            Trevenant  85     110       76       65       82     56
# Mean HP: 71.0
# Mean Attack: 130.0
# Mean Defense: 72.0
# Mean Sp. Atk: 80.33333333333333
# Mean Sp. Def: 76.0
# Mean Speed: 65.33333333333333
#
# Cluster 4
#            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 99       Gastly  30      35       30      100       35     80
# 100     Haunter  45      50       45      115       55     95
# 101      Gengar  60      65       60      130       75    110
# 215  Misdreavus  60      60       60       85       85     85
# 477   Mismagius  60      60       60      105      105    105
# Mean HP: 51.0
# Mean Attack: 54.0
# Mean Defense: 51.0
# Mean Sp. Atk: 107.0
# Mean Sp. Def: 71.0
# Mean Speed: 95.0
#
# Cluster 5
#                       Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 385                Shuppet  44      75       35       63       33     45
# 472               Drifloon  90      50       34       60       44     70
# 669                Lampent  60      40       60       95       60     55
# 778               Phantump  43      70       48       50       60     38
# 780  PumpkabooAverage Size  49      66       70       44       55     51
# 781    PumpkabooSmall Size  44      66       70       44       55     56
# 782    PumpkabooLarge Size  54      66       70       44       55     46
# 783    PumpkabooSuper Size  59      66       70       44       55     41
# Mean HP: 55.375
# Mean Attack: 62.375
# Mean Defense: 57.125
# Mean Sp. Atk: 55.5
# Mean Sp. Def: 52.125
# Mean Speed: 50.25
#
# Cluster 6
#            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 389    Dusclops  40      70      130       60      130     25
# 490   Spiritomb  50      92      108       92      108     35
# 529    Dusknoir  45     100      135       65      135     45
# 624  Cofagrigus  58      50      145       95      105     30
# Mean HP: 48.25
# Mean Attack: 78.0
# Mean Defense: 129.5
# Mean Sp. Atk: 78.0
# Mean Sp. Def: 119.5
# Mean Speed: 33.75
#
# Cluster 7
#                   Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 102  GengarMega Gengar  60      65       80      170       95    130
# 670         Chandelure  60      55       90      145       90     80
# Mean HP: 60.0
# Mean Attack: 60.0
# Mean Defense: 85.0
# Mean Sp. Atk: 157.5
# Mean Sp. Def: 92.5
# Mean Speed: 105.0
#
# Cluster 8
#          Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 473  Drifblim  150      80       44       90       54     80
# Mean HP: 150.0
# Mean Attack: 80.0
# Mean Defense: 44.0
# Mean Sp. Atk: 90.0
# Mean Sp. Def: 54.0
# Mean Speed: 80.0
#
# Ice
# -----------
# Cluster 0
#                   Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 133               Jynx   65      50       35      115       95     95
# 156           Articuno   90      85      100       95      125     85
# 239          Piloswine  100     100       80       60       60     50
# 396             Glalie   80      80       80       80       80     80
# 397  GlalieMega Glalie   80     120       80      120       80    100
# 400            Walrein  110      80       90       95       90     65
# 415             Regice   80      50      100      100      200     50
# 522            Glaceon   65      60      110      130       95     65
# 524          Mamoswine  110     130       80       70       60     80
# 530           Froslass   70      80       70       80       70    110
# 645          Vanilluxe   71      95       85      110       95     79
# 675            Beartic   95     110       80       70       80     50
# 676          Cryogonal   70      50       30       95      135    105
# Mean HP: 83.53846153846153
# Mean Attack: 83.84615384615384
# Mean Defense: 78.46153846153847
# Mean Sp. Atk: 93.84615384615384
# Mean Sp. Def: 97.3076923076923
# Mean Speed: 78.0
#
# Cluster 1
#           Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 238     Swinub  50      50       40       30       30     50
# 243   Delibird  45      55       45       65       45     75
# 257   Smoochum  45      30       15       85       65     65
# 395    Snorunt  50      50       50       50       50     50
# 398     Spheal  70      40       50       55       50     25
# 399     Sealeo  90      60       70       75       70     45
# 643  Vanillite  36      50       50       65       60     44
# 644  Vanillish  51      65       65       80       75     59
# 674    Cubchoo  55      70       40       60       40     40
# 788   Bergmite  55      69       85       32       35     28
# 789    Avalugg  95     117      184       44       46     28
# Mean HP: 58.36363636363637
# Mean Attack: 59.63636363636363
# Mean Defense: 63.09090909090909
# Mean Sp. Atk: 58.27272727272727
# Mean Sp. Def: 51.45454545454545
# Mean Speed: 46.27272727272727
#
# Dragon
# -----------
# Cluster 0
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 161                Dragonite   91     134       95      100      100     80
# 366      AltariaMega Altaria   75     110      110      110      105     80
# 408                Salamence   95     135       80      110       80    100
# 409  SalamenceMega Salamence   95     145      130      120       90    120
# 417                   Latias   80      80       90      110      130    110
# 418        LatiasMega Latias   80     100      120      140      150    110
# 419                   Latios   80      90       80      130      110    110
# 420        LatiosMega Latios   80     130      100      160      120    110
# 425                 Rayquaza  105     150       90      150       90     95
# 426    RayquazaMega Rayquaza  105     180      100      180      100    115
# 493                 Garchomp  108     130       95       80       85    102
# 494    GarchompMega Garchomp  108     170      115      120       95     92
# 673                  Haxorus   76     147       90       60       70     97
# 706                 Reshiram  100     120      100      150      120     90
# 707                   Zekrom  100     150      120      120      100     90
# 710                   Kyurem  125     130       90      130       90     95
# 711       KyuremBlack Kyurem  125     170      100      120       90     95
# 712       KyuremWhite Kyurem  125     120       90      170      100     95
# 776                   Goodra   90     100       70      110      150     80
# 794         Zygarde50% Forme  108     100      121       81       95     95
# Mean HP: 97.55
# Mean Attack: 129.55
# Mean Defense: 99.3
# Mean Sp. Atk: 122.55
# Mean Sp. Def: 103.5
# Mean Speed: 98.05
#
# Cluster 1
#           Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 159    Dratini  41      64       45       50       50     50
# 160  Dragonair  61      84       65       70       70     70
# 365    Altaria  75      70       90       70      105     80
# 406      Bagon  45      75       60       40       30     50
# 407    Shelgon  65      95      100       60       50     50
# 491      Gible  58      70       45       40       45     42
# 492     Gabite  68      90       65       50       55     82
# 671       Axew  46      87       60       30       40     57
# 672    Fraxure  66     117       70       40       50     67
# 682  Druddigon  77     120       90       60       90     48
# 774      Goomy  45      50       35       55       75     40
# 775    Sliggoo  68      75       53       83      113     60
# Mean HP: 59.583333333333336
# Mean Attack: 83.08333333333333
# Mean Defense: 64.83333333333333
# Mean Sp. Atk: 54.0
# Mean Sp. Def: 64.41666666666667
# Mean Speed: 58.0
#
# Dark
# -----------
# Cluster 0
#                     Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 212              Umbreon   95      65      110       60      130     65
# 233              Sneasel   55      95       55       35       75    115
# 246             Houndour   45      60       30       80       50     65
# 284            Poochyena   35      55       35       30       30     35
# 285            Mightyena   70      90       70       60       60     70
# 326              Sableye   50      75       75       65       65     50
# 327  SableyeMega Sableye   50      85      125       85      115     20
# 568             Purrloin   41      50       37       50       37     66
# 620              Scraggy   50      75       70       35       70     48
# 621              Scrafty   65      90      115       45      115     58
# 631                Zorua   40      65       40       80       40     65
# 685             Pawniard   45      85       70       40       40     60
# 686              Bisharp   65     125      100       60       70     70
# 690              Vullaby   70      55       75       45       65     60
# 691            Mandibuzz  110      65      105       55       95     80
# 694                Deino   52      65       50       45       50     38
# 695             Zweilous   72      85       70       65       70     58
# 756                Inkay   53      54       53       37       46     45
# 757              Malamar   86      92       88       68       75     73
# Mean HP: 60.473684210526315
# Mean Attack: 75.3157894736842
# Mean Defense: 72.26315789473684
# Mean Sp. Atk: 54.73684210526316
# Mean Sp. Def: 68.3157894736842
# Mean Speed: 60.05263157894737
#
# Cluster 1
#                       Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 213                Murkrow   60      85       42       85       42     91
# 247               Houndoom   75      90       50      110       80     95
# 248  HoundoomMega Houndoom   75      90       90      140       90    115
# 392                  Absol   65     130       60       75       60     75
# 393        AbsolMega Absol   65     150       60      115       60    115
# 478              Honchkrow  100     125       52      105       52     71
# 512                Weavile   70     120       65       45       85    125
# 549                Darkrai   70      90       90      135       90    125
# 569                Liepard   64      88       50       88       50    106
# 632                Zoroark   60     105       60      120       60    105
# 696              Hydreigon   92     105       90      125       90     98
# 793                Yveltal  126     131       95      131       98     99
# Mean HP: 76.83333333333333
# Mean Attack: 109.08333333333333
# Mean Defense: 67.0
# Mean Sp. Atk: 106.16666666666667
# Mean Sp. Def: 71.41666666666667
# Mean Speed: 101.66666666666667
#
# Steel
# -----------
# Cluster 0
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 412                Metagross   80     135      130       95       90     70
# 413  MetagrossMega Metagross   80     145      150      105      110    110
# 427                  Jirachi  100     100      100      100      100    100
# 540                   Dialga  100     120      120      150      100     90
# 699                 Cobalion   91      90      129       90       72    108
# Mean HP: 90.2
# Mean Attack: 118.0
# Mean Defense: 125.8
# Mean Sp. Atk: 108.0
# Mean Sp. Def: 94.4
# Mean Speed: 95.6
#
# Cluster 1
#         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 330     Aron  50      70      100       40       40     30
# 410   Beldum  40      55       80       35       60     30
# 484  Bronzor  57      24       86       24       86     23
# 660    Klink  40      55       70       45       60     30
# 748  Honedge  45      80      100       35       37     28
# Mean HP: 46.4
# Mean Attack: 56.8
# Mean Defense: 87.2
# Mean Sp. Atk: 35.8
# Mean Sp. Def: 56.6
# Mean Speed: 28.2
#
# Cluster 2
#                       Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 416              Registeel  80      75      150       75      150     50
# 485               Bronzong  67      89      116       79      116     33
# 751  AegislashShield Forme  60      50      150       50      150     60
# Mean HP: 69.0
# Mean Attack: 71.33333333333333
# Mean Defense: 138.66666666666666
# Mean Sp. Atk: 68.0
# Mean Sp. Def: 138.66666666666666
# Mean Speed: 47.666666666666664
#
# Cluster 3
#                     Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 223              Steelix  75      85      200       55       65     30
# 224  SteelixMega Steelix  75     125      230       55       95     30
# 332               Aggron  70     110      180       60       60     50
# 333    AggronMega Aggron  70     140      230       60       80     50
# Mean HP: 72.5
# Mean Attack: 115.0
# Mean Defense: 210.0
# Mean Sp. Atk: 57.5
# Mean Sp. Def: 75.0
# Mean Speed: 40.0
#
# Cluster 4
#                      Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 245              Skarmory  65      80      140       40       70     70
# 328                Mawile  50      85       85       55       55     50
# 329     MawileMega Mawile  50     105      125       55       95     50
# 331                Lairon  60      90      140       50       50     40
# 411                Metang  60      75      100       55       80     50
# 661                 Klang  60      80       95       70       85     50
# 662             Klinklang  60     100      115       70       85     90
# 749              Doublade  59     110      150       45       49     35
# 750  AegislashBlade Forme  60     150       50      150       50     60
# 777                Klefki  57      80       91       80       87     75
# Mean HP: 58.1
# Mean Attack: 95.5
# Mean Defense: 109.1
# Mean Sp. Atk: 67.0
# Mean Sp. Def: 70.6
# Mean Speed: 57.0
#
# Flying
# -----------
# Cluster 0
#        Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 790  Noibat  40      30       35       45       40     55
# Mean HP: 40.0
# Mean Attack: 30.0
# Mean Defense: 35.0
# Mean Sp. Atk: 45.0
# Mean Sp. Def: 40.0
# Mean Speed: 55.0
#
# Cluster 1
#                         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 702  TornadusIncarnate Forme  79     115       70      125       80    111
# 703    TornadusTherian Forme  79     100       80      110       90    121
# 791                  Noivern  85      70       80       97       80    123
# Mean HP: 81.0
# Mean Attack: 95.0
# Mean Defense: 76.66666666666667
# Mean Sp. Atk: 110.66666666666667
# Mean Sp. Def: 83.33333333333333
# Mean Speed: 118.33333333333333
